# %% [markdown]
# <div style="text-align: center; background-color: #ccffcc; color: #006600; padding: 20px; border-radius: 5px;">
#     <h2 style="margin: 0; font-size: 13px;">Don't forget to upvote if you liked the notebook</h2>
# </div>

# %% [markdown]
# ## Introduction to pandas

# %% [markdown]
# Pandas is an open-source Python library that provides easy-to-use data structures and data analysis tools. It is widely used for data manipulation, data analysis, and data cleaning tasks in the field of data science and machine learning. Pandas is built on top of NumPy, another popular Python library for
# numerical computing.
#
# Pandas is a fast,powerful,and easy to use open source data analysis and manipulation tool,built on top of the python programming language.

# %% [markdown]
# ## Pandas Series
# A pandas Series is like a column in a table. It is a 1-D array holding data of any type.
# Series: A one-dimensional labeled array capable of holding data of any type.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series from lists

# %%
# string
country = ['Germany','Itlay','Egypt','France','China']
pd.Series(country)
# Out:
# 0    Germany
# 1      Itlay
# 2      Egypt
# 3     France
# 4      China
# dtype: object

# %%
# integers
marks = [76,87,43,54,98]
pd.Series(marks)
# Out:
# 0    76
# 1    87
# 2    43
# 3    54
# 4    98
# dtype: int64

# %%
# custom index
marks = [76,87,43,54,98]
subjects = ['english','physics','chemistry','maths','IT']
pd.Series(marks,index=subjects)
# Out:
# english      76
# physics      87
# chemistry    43
# maths        54
# IT           98
# dtype: int64

# %%
#setting a name
pd.Series(marks,index=subjects,name='Arun marks')
# Out:
# english      76
# physics      87
# chemistry    43
# maths        54
# IT           98
# Name: Arun marks, dtype: int64

# %% [markdown]
# ## Series from dict

# %%
marks = {
    'english':76,
    'physics':67,
    'chemistry':43,
    'maths':54,
    'IT':98
}
marks_series = pd.Series(marks)
marks_series
# Out:
# english      76
# physics      67
# chemistry    43
# maths        54
# IT           98
# dtype: int64

# %% [markdown]
# ## Series Attributes

# %%
# size
marks_series.size
# Out:
# 5

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# is_unique
marks_series.is_unique
# Out:
# True

# %%
#index
marks_series.index
# Out:
# Index(['english', 'physics', 'chemistry', 'maths', 'IT'], dtype='object')

# %%
#values
marks_series.values
#type(marks_series.values)
# Out:
# array([76, 67, 43, 54, 98])

# %% [markdown]
# ## Series Indexing

# %%
# Series works on positive indexing not work on negative indexing(works only if the indexes are string)
# integer indexing
x = pd.Series([34,56,78,34,23,32,56,76,57,83])
x[0]
# Out:
# 34

# %%
#slicing
x[2:5]
# Out:
# 2    78
# 3    34
# 4    23
# dtype: int64

# %%
#fancy indexing
x[[1,4,3,2]]
# Out:
# 1    56
# 4    23
# 3    34
# 2    78
# dtype: int64

# %% [markdown]
# ## Editing series

# %%
# using indexing
x[0] = 89
x
# Out:
# 0    89
# 1    56
# 2    78
# 3    34
# 4    23
# 5    32
# 6    56
# 7    76
# 8    57
# 9    83
# dtype: int64

# %%
# what if an index does not exist
marks_series['sst'] = 91
marks_series
# Out:
# english      76
# physics      67
# chemistry    43
# maths        54
# IT           98
# sst          91
# dtype: int64

# %%
# slicing
marks_series[2:4] = [50,51]
marks_series
# Out:
# english      76
# physics      67
# chemistry    50
# maths        51
# IT           98
# sst          91
# dtype: int64

# %%
# fancy indexing
marks_series[[0,3,4]] = [0,0,0]
marks_series
# Out:
# english       0
# physics      67
# chemistry    50
# maths         0
# IT            0
# sst          91
# dtype: int64

# %%
# Arthmetic operators
100 - marks_series
# Out:
# english      100
# physics       33
# chemistry     50
# maths        100
# IT           100
# sst            9
# dtype: int64

# %%
#relational operators
x >= 50
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
# find no of 50's 
x[x >= 50].size
# Out:
# 7

# %% [markdown]
# ## DataFrame
# Any structure that got rows and columns is called DataFrame in pandas

# %% [markdown]
# ![](https://media.geeksforgeeks.org/wp-content/uploads/20200414224825/f115.png)

# %%
#using lists
students_data = [
    [100,80,10],
    [93,76,7],
    [120,97,14],
    [80,50,2]
]
pd.DataFrame(students_data,columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   93     76        7
# 2  120     97       14
# 3   80     50        2

# %%
# using dicts

students_dict = {
    'name':['Ankit','Gaurav','Sonalika','Rashmi','Shivani'],
    'iq':[100,90,120,102,98],
    'marks':[80,70,98,89,87],
    'package':[10,7,14,4,20]
}
students = pd.DataFrame(students_dict)
students.set_index('name',inplace=True)
students
# Out:
#            iq  marks  package
# name
# Ankit     100     80       10
# Gaurav     90     70        7
# Sonalika  120     98       14
# Rashmi    102     89        4
# Shivani    98     87       20

# %%
# using read_csv
movies = pd.read_csv('/kaggle/input/top-rated-movies/movies.csv')
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
ipl = pd.read_csv('/kaggle/input/cricket-and-coding-crack-the-challenge/training_dataset/DataSet/IPL_Matches_Result_2008_2022.csv')
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %% [markdown]
# ## DataFrame Attributes and Methods

# %%
#shape
movies.shape
#ipl.shape
# Out:
# (1629, 18)

# %%
#dtypes
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
#index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
# columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
#values
students.values
# Out:
# array([[100,  80,  10],
#        [ 90,  70,   7],
#        [120,  98,  14],
#        [102,  89,   4],
#        [ 98,  87,  20]])

# %%
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# head and tail
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
ipl.tail(3)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 947             Delhi Daredevils       Rajasthan Royals
# 948              Kings XI Punjab    Chennai Super Kings
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 947          bat         N       Delhi Daredevils  Wickets     9.0    NaN
# ...

# %%
#sample
ipl.sample(5)
# Out:
#           ID           City        Date Season MatchNumber  \
# 667   548343        Chennai  2012-04-28   2012          37
# 696   548311  Visakhapatnam  2012-04-07   2012           6
# 688   548319     Chandigarh  2012-04-12   2012          14
# 118  1254073         Mumbai  2021-04-22   2021          16
# 267  1136607         Mumbai  2018-05-13   2018          47
#
#                    Team1                        Team2  \
# 667  Chennai Super Kings              Kings XI Punjab
# 696      Deccan Chargers          Chennai Super Kings
# 688      Kings XI Punjab                Pune Warriors
# 118     Rajasthan Royals  Royal Challengers Bangalore
# 267       Mumbai Indians             Rajasthan Royals
#
#                                                  Venue  \
# 667                    MA Chidambaram Stadium, Chepauk
# 696  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 688         Punjab Cricket Association Stadium, Mohali
# 118                           Wankhede Stadium, Mumbai
# ...

# %%
#info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
#describe
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
#isnull
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# duplicated
ipl.duplicated().sum()
# Out:
# 0

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
# rename
students.rename(columns={'marks':'percent','package':'lpa'})
# Out:
#            iq  percent  lpa
# name
# Ankit     100       80   10
# Gaurav     90       70    7
# Sonalika  120       98   14
# Rashmi    102       89    4
# Shivani    98       87   20

# %% [markdown]
# ## Math Methods

# %%
# sum -> axis argument
students.sum()
# Out:
# iq         510
# marks      424
# package     55
# dtype: int64

# %%
students.sum(axis=1)
# Out:
# name
# Ankit       190
# Gaurav      167
# Sonalika    232
# Rashmi      195
# Shivani     205
# dtype: int64

# %%
students.mean()
# Out:
# iq         102.0
# marks       84.8
# package     11.0
# dtype: float64

# %%
students.min()
# Out:
# iq         90
# marks      70
# package     4
# dtype: int64

# %%
students.max()
# Out:
# iq         120
# marks       98
# package     20
# dtype: int64

# %%
# standard deviation
students.std()
# Out:
# iq         11.045361
# marks      10.473777
# package     6.244998
# dtype: float64

# %%
# variance
students.var()
# Out:
# iq         122.0
# marks      109.7
# package     39.0
# dtype: float64

# %% [markdown]
# ## Selcting cols from a DataFrame

# %%
# single_cols
type(movies['title_x'])
# Out:
# pandas.core.series.Series

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
# slicing   # multiple cols
movies[['title_x','year_of_release','actors']]
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %% [markdown]
# ## Selecting rows from a DataFrame
# * iloc-searches using index positions
# * loc-searches using index labels

# %%
#single row
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
# multiple rows
movies.iloc[5:16:2]
# Out:
#               title_x    imdb_id  \
# 5         Soni (film)  tt6078866
# 7          Bombairiya  tt4971258
# 9    Thackeray (film)  tt7777196
# 11          Gully Boy  tt2395469
# 13      Total Dhamaal  tt7639372
# 15  Badla (2019 film)  tt8130968
#
#                                           poster_path  \
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 13  https://upload.wikimedia.org/wikipedia/en/thum...
# 15  https://upload.wikimedia.org/wikipedia/en/0/0c...
#
#                                           wiki_link        title_y  \
# 5         https://en.wikipedia.org/wiki/Soni_(film)           Soni
# 7          https://en.wikipedia.org/wiki/Bombairiya     Bombairiya
# 9    https://en.wikipedia.org/wiki/Thackeray_(film)      Thackeray
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# ...

# %%
# fancy indexing
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
# loc
students
# Out:
#            iq  marks  package
# name
# Ankit     100     80       10
# Gaurav     90     70        7
# Sonalika  120     98       14
# Rashmi    102     89        4
# Shivani    98     87       20

# %%
students.loc['Gaurav']
# Out:
# iq         90
# marks      70
# package     7
# Name: Gaurav, dtype: int64

# %%
#slicing
students.loc['Ankit':'Sonalika']
# Out:
#            iq  marks  package
# name
# Ankit     100     80       10
# Gaurav     90     70        7
# Sonalika  120     98       14

# %%
#fancy indexing
students.loc[['Ankit','Shivani','Rashmi']]
# Out:
#           iq  marks  package
# name
# Ankit    100     80       10
# Shivani   98     87       20
# Rashmi   102     89        4

# %%
students.iloc[:4]
# Out:
#            iq  marks  package
# name
# Ankit     100     80       10
# Gaurav     90     70        7
# Sonalika  120     98       14
# Rashmi    102     89        4

# %%
# Selecting both rows and columns
movies.iloc[0:4,0:4]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India

# %% [markdown]
# ## Filtering a DataFrame

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# find all the final winners
new_df = ipl[ipl['MatchNumber'] == 'Final']
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#another method
ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super over  finishes have occured
ipl[ipl['SuperOver'] == 'Y'].shape
# Out:
# (14, 20)

# %%
# how many matches has csk won in kolkata
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in percentage
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
# Action movies with rating higher than 7.5
A = movies['genres'].str.split('|').apply(lambda x:'Action' in x)
# second method  A = movies['genres'].str.contains('Action')
B = movies['imdb_rating'] > 7.5
movies[A & B].shape[0]
# Out:
# 33

# %%
# write a function that can return the track record of 2 teams against each other
def get_team_track_record(team1, team2, ipl):
    matches = ipl[((ipl['Team1'] == team1) & (ipl['Team2'] == team2)) |
                      ((ipl['Team1'] == team2) & (ipl['Team2'] == team1))]
    team1_wins = (matches['WinningTeam'] == team1).sum()
    team2_wins = (matches['WinningTeam'] == team2).sum()
    total_matches = len(matches)
    
    return {
        f"{team1} wins": team1_wins,
        f"{team2} wins": team2_wins,
        "Total matches": total_matches
    }

# Example usage
team1 = "Mumbai Indians"
team2 = "Chennai Super Kings"
track_record = get_team_track_record(team1, team2, ipl)
print(track_record)
# Out:
# {'Mumbai Indians wins': 20, 'Chennai Super Kings wins': 14, 'Total matches': 34}

# %% [markdown]
# ## Adding new columns

# %%
# completely row
movies['Country'] = 'India'
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# from existing ones
movies.dropna(inplace=True)

# %%
movies['lead actor'] = movies['actors'].str.split('|').apply(lambda x:x[0])
movies.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
# ...

# %% [markdown]
# # Important DataFrame Functions

# %%
#astype
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl['Season'] = ipl['Season'].astype('category')

# %% [markdown]
# ## On Iris Dataset

# %%
list = [10, 20, 30, 40, 50]
labels = ['A', 'B', 'C', 'D', 'E']
arr = np.array([10,20,30,40,50])
dic = {'A':10,'B':20,'C':30, 'D':40, "E":50}

# %%
pd.Series(data=list)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.Series(data=list,index=labels) #the labels can be changed

#Also, writing "data=" and "index=" is not neccessary as they are first 2 arguments by default
pd.Series(list, labels)
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
pd.Series(arr, labels) #doing the same with numpy arrays
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
#We can do all arithmetic operations on Series
ser1 = pd.Series(arr, labels)
ser2 = pd.Series(dic)

ser1 + ser2
# Out:
# A     20
# B     40
# C     60
# D     80
# E    100
# dtype: int64

# %% [markdown]
# DataFrame: A two-dimensional labeled data structure, similar to a spreadsheet or SQL table, with columns of potentially different data types.

# %%
dict1 = {
    "name":['harry','rohan','sahil','shubh'],
    "marks":[92,54,65,19],
    "city":['rampur','kolkata','barielly','delhi']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#     name  marks      city
# 0  harry     92    rampur
# 1  rohan     54   kolkata
# 2  sahil     65  barielly
# 3  shubh     19     delhi

# %%
df.to_csv('friends.csv')

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   57.50000
# std    30.22692
# min    19.00000
# 25%    45.25000
# 50%    59.50000
# 75%    71.75000
# max    92.00000

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     54  kolkata

# %%
df.tail(2)
# Out:
#     name  marks      city
# 2  sahil     65  barielly
# 3  shubh     19     delhi

# %%
df.index=[1,2,3,4]

# %%
df
# Out:
#     name  marks      city
# 1  harry     92    rampur
# 2  rohan     54   kolkata
# 3  sahil     65  barielly
# 4  shubh     19     delhi

# %%
newdf=pd.DataFrame(np.random.rand(335,5),index=np.arange(335))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.992948  0.993586  0.203371  0.204615  0.734358
# 1    0.962558  0.498844  0.218465  0.367520  0.430987
# 2    0.661971  0.818487  0.754545  0.447575  0.347687
# 3    0.173104  0.255733  0.779904  0.129099  0.023724
# 4    0.533614  0.294148  0.907086  0.074381  0.443272
# ..        ...       ...       ...       ...       ...
# 330  0.142709  0.599673  0.605400  0.186997  0.067752
# 331  0.363816  0.927780  0.988656  0.939720  0.963304
# 332  0.552401  0.163309  0.083266  0.106655  0.411982
# 333  0.247973  0.478363  0.742056  0.780171  0.912376
# 334  0.415671  0.521841  0.159438  0.693701  0.672936
#
# [335 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.992948  0.993586  0.203371  0.204615  0.734358
# 1  0.962558  0.498844  0.218465  0.367520  0.430987
# 2  0.661971  0.818487  0.754545  0.447575  0.347687
# 3  0.173104  0.255733  0.779904  0.129099  0.023724
# 4  0.533614  0.294148  0.907086  0.074381  0.443272

# %%
newdf.tail()
# Out:
#             0         1         2         3         4
# 330  0.142709  0.599673  0.605400  0.186997  0.067752
# 331  0.363816  0.927780  0.988656  0.939720  0.963304
# 332  0.552401  0.163309  0.083266  0.106655  0.411982
# 333  0.247973  0.478363  0.742056  0.780171  0.912376
# 334  0.415671  0.521841  0.159438  0.693701  0.672936

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Data Alignment
# Pandas aligns data automatically based on row and column labels, making it easy to perform operations on different datasets.

# %%
import pandas as pd

series1 = pd.Series([10, 20, 30], index=['A', 'B', 'C'])
series2 = pd.Series([100, 200, 300], index=['B', 'C', 'D'])

# Performing addition on two Series with different indices
result = series1 + series2
print(result)
# Out:
# A      NaN
# B    120.0
# C    230.0
# D      NaN
# dtype: float64

# %% [markdown]
# ## Missing Data Handling
# Pandas handles missing data efficiently and provides methods to fill, drop, or interpolate missing values

# %%
import pandas as pd

data = {
    'A': [1, 2, None, 4],
    'B': [5, None, 7, 8],
}
df = pd.DataFrame(data)

# %%
# Checking for missing values
print(df.isnull())
# Out:
#        A      B
# 0  False  False
# 1  False   True
# 2   True  False
# 3  False  False

# %%
# Filling missing values with a specific value
filled_df = df.fillna(0)
print(filled_df)
# Out:
#      A    B
# 0  1.0  5.0
# 1  2.0  0.0
# 2  0.0  7.0
# 3  4.0  8.0

# %%
# Dropping rows with missing values
dropped_df = df.dropna()
print(dropped_df)
# Out:
#      A    B
# 0  1.0  5.0
# 3  4.0  8.0

# %% [markdown]
# ## Data Input/Output
# Pandas supports reading and writing data in various file formats, including CSV, Excel, SQL databases, and more

# %%
# Reading data from a CSV file

import pandas as pd

# Assuming 'iris.csv' is in a subdirectory named 'iris_data' within the 'input' directory
df = pd.read_csv('/kaggle/input/irisraw/irisraw.csv')

# %%
df
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['sepal length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length, Length: 150, dtype: float64

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# ..            ...          ...           ...          ...             ...
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 0             5.1          3.5           1.4          0.2     Iris-setosa
#
# [150 rows x 5 columns]

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#             species  sepal width  sepal length  petal width  petal length
# 0       Iris-setosa          3.5           5.1          0.2           1.4
# 1       Iris-setosa          3.0           4.9          0.2           1.4
# 2       Iris-setosa          3.2           4.7          0.2           1.3
# 3       Iris-setosa          3.1           4.6          0.2           1.5
# 4       Iris-setosa          3.6           5.0          0.2           1.4
# ..              ...          ...           ...          ...           ...
# 145  Iris-virginica          3.0           6.7          2.3           5.2
# 146  Iris-virginica          2.5           6.3          1.9           5.0
# 147  Iris-virginica          3.0           6.5          2.0           5.2
# 148  Iris-virginica          3.4           6.2          2.3           5.4
# 149  Iris-virginica          3.0           5.9          1.8           5.1
#
# [150 rows x 5 columns]

# %%
newdf.loc[0,0]=654

# %%
newdf.head()
# Out:
#             0         1         2         3         4
# 0  654.000000  0.993586  0.203371  0.204615  0.734358
# 1    0.962558  0.498844  0.218465  0.367520  0.430987
# 2    0.661971  0.818487  0.754545  0.447575  0.347687
# 3    0.173104  0.255733  0.779904  0.129099  0.023724
# 4    0.533614  0.294148  0.907086  0.074381  0.443272

# %%
newdf.loc[0,0]=654
newdf.head(2)
# Out:
#             0         1         2         3         4
# 0  654.000000  0.993586  0.203371  0.204615  0.734358
# 1    0.962558  0.498844  0.218465  0.367520  0.430987

# %%
newdf.loc[0,'A']=65445
newdf.head(3)
# Out:
#             0         1         2         3         4        A
# 0  654.000000  0.993586  0.203371  0.204615  0.734358  65445.0
# 1    0.962558  0.498844  0.218465  0.367520  0.430987      NaN
# 2    0.661971  0.818487  0.754545  0.447575  0.347687      NaN

# %%
newdf.drop(0,axis=1)
#remove column
# Out:
#             1         2         3         4        A
# 0    0.993586  0.203371  0.204615  0.734358  65445.0
# 1    0.498844  0.218465  0.367520  0.430987      NaN
# 2    0.818487  0.754545  0.447575  0.347687      NaN
# 3    0.255733  0.779904  0.129099  0.023724      NaN
# 4    0.294148  0.907086  0.074381  0.443272      NaN
# ..        ...       ...       ...       ...      ...
# 330  0.599673  0.605400  0.186997  0.067752      NaN
# 331  0.927780  0.988656  0.939720  0.963304      NaN
# 332  0.163309  0.083266  0.106655  0.411982      NaN
# 333  0.478363  0.742056  0.780171  0.912376      NaN
# 334  0.521841  0.159438  0.693701  0.672936      NaN
#
# [335 rows x 5 columns]

# %%
newdf.drop(0,axis=0)
#remove row
# Out:
#             0         1         2         3         4   A
# 1    0.962558  0.498844  0.218465  0.367520  0.430987 NaN
# 2    0.661971  0.818487  0.754545  0.447575  0.347687 NaN
# 3    0.173104  0.255733  0.779904  0.129099  0.023724 NaN
# 4    0.533614  0.294148  0.907086  0.074381  0.443272 NaN
# 5    0.762824  0.052299  0.354870  0.010653  0.356333 NaN
# ..        ...       ...       ...       ...       ...  ..
# 330  0.142709  0.599673  0.605400  0.186997  0.067752 NaN
# 331  0.363816  0.927780  0.988656  0.939720  0.963304 NaN
# 332  0.552401  0.163309  0.083266  0.106655  0.411982 NaN
# 333  0.247973  0.478363  0.742056  0.780171  0.912376 NaN
# 334  0.415671  0.521841  0.159438  0.693701  0.672936 NaN
#
# [334 rows x 6 columns]

# %%
newdf=newdf.drop(0,axis=1)

# %%
newdf
# Out:
#             1         2         3         4        A
# 0    0.993586  0.203371  0.204615  0.734358  65445.0
# 1    0.498844  0.218465  0.367520  0.430987      NaN
# 2    0.818487  0.754545  0.447575  0.347687      NaN
# 3    0.255733  0.779904  0.129099  0.023724      NaN
# 4    0.294148  0.907086  0.074381  0.443272      NaN
# ..        ...       ...       ...       ...      ...
# 330  0.599673  0.605400  0.186997  0.067752      NaN
# 331  0.927780  0.988656  0.939720  0.963304      NaN
# 332  0.163309  0.083266  0.106655  0.411982      NaN
# 333  0.478363  0.742056  0.780171  0.912376      NaN
# 334  0.521841  0.159438  0.693701  0.672936      NaN
#
# [335 rows x 5 columns]

# %%
df.loc[[1,2],['sepal length','petal length']]
# Out:
#    sepal length  petal length
# 1           4.9           1.4
# 2           4.7           1.3

# %%
df.loc[[1,2],:]
# Out:
#    sepal length  sepal width  petal length  petal width      species
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
df.loc[:,['sepal length','petal length']]
# Out:
#      sepal length  petal length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %%
df.iloc[0,4]
#this is used to find any data without knowing its location name ,just by location
# Out:
# 'Iris-setosa'

# %%
df.iloc[[0,4],[3,4]]
# Out:
#    petal width      species
# 0          0.2  Iris-setosa
# 4          0.2  Iris-setosa

# %%
df.loc[:,['sepal length']] #this is type of dataframe
# Out:
#      sepal length
# 0             5.1
# 1             4.9
# 2             4.7
# 3             4.6
# 4             5.0
# ..            ...
# 145           6.7
# 146           6.3
# 147           6.5
# 148           6.2
# 149           5.9
#
# [150 rows x 1 columns]

# %%
df.loc[:,('sepal length','petal length')]# this is a type of dataframe because more than one column is present
# Out:
#      sepal length  petal length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %%
data = {
    "name":['harry','rohan','sahil','shubh','karan','sona'],
    "marks":[11,12,13,14,15,16],
    "city":['rampur','kolkata','barielly','delhi','jaipur','jodhpur']
}

# %%
import pandas as pd

# %%
df3=pd.DataFrame(data)

# %%
df3
# Out:
#     name  marks      city
# 0  harry     11    rampur
# 1  rohan     12   kolkata
# 2  sahil     13  barielly
# 3  shubh     14     delhi
# 4  karan     15    jaipur
# 5   sona     16   jodhpur

# %%
marks=df3.loc[:,["marks"]]

# %%
marks
# Out:
#    marks
# 0     11
# 1     12
# 2     13
# 3     14
# 4     15
# 5     16

# %%
#df4.reset_index(inplace = True)

# %%
marks
# Out:
#    marks
# 0     11
# 1     12
# 2     13
# 3     14
# 4     15
# 5     16

# %%
df4=marks>14

# %%
df4
# Out:
#    marks
# 0  False
# 1  False
# 2  False
# 3  False
# 4   True
# 5   True
